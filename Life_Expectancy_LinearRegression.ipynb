# %%
import pandas as pd

# %% [markdown]
# #Loading the dataset into dataframe

# %%
df=pd.read_csv("Life Expectancy Data.csv")

# %% [markdown]
# # Checking the null values present in the dataset

# %%
df.isnull().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
df["Life expectancy "]
# Out:
# 0       65.0
# 1       59.9
# 2       59.9
# 3       59.5
# 4       59.2
#         ...
# 2933    44.3
# 2934    44.5
# 2935    44.8
# 2936    45.3
# 2937    46.0
# Name: Life expectancy , Length: 2938, dtype: float64

# %% [markdown]
# # using simple imputer to replace missing value with th mean of the column

# %%
from sklearn.impute import SimpleImputer
imputer=SimpleImputer(strategy='mean')
df['Life expectancy ']=imputer.fit_transform(df[['Life expectancy ']])
df['Adult Mortality']=imputer.fit_transform(df[['Adult Mortality']])
df['Alcohol']=imputer.fit_transform(df[['Alcohol']])
df['Hepatitis B']=imputer.fit_transform(df[['Hepatitis B']])
df[' BMI ']=imputer.fit_transform(df[[' BMI ']])
df['Polio']=imputer.fit_transform(df[['Polio']])
df['Total expenditure']=imputer.fit_transform(df[['Total expenditure']])
df['Diphtheria ']=imputer.fit_transform(df[['Diphtheria ']])
df['GDP']=imputer.fit_transform(df[['GDP']])
df['Population']=imputer.fit_transform(df[['Population']])
df[' thinness  1-19 years']=imputer.fit_transform(df[[' thinness  1-19 years']])
df[' thinness 5-9 years']=imputer.fit_transform(df[[' thinness 5-9 years']])
df['Income composition of resources']=imputer.fit_transform(df[['Income composition of resources']])
df['Schooling']=imputer.fit_transform(df[['Schooling']])

# %%
df.isnull().sum()
# Out:
# Country                            0
# Year                               0
# Status                             0
# Life expectancy                    0
# Adult Mortality                    0
# infant deaths                      0
# Alcohol                            0
# percentage expenditure             0
# Hepatitis B                        0
# Measles                            0
#  BMI                               0
# under-five deaths                  0
# Polio                              0
# Total expenditure                  0
# Diphtheria                         0
#  HIV/AIDS                          0
# GDP                                0
# Population                         0
#  thinness  1-19 years              0
#  thinness 5-9 years                0
# Income composition of resources    0
# Schooling                          0
# dtype: int64

# %% [markdown]
# # Checking correlation between different fields

# %%
df.corr()
# Out:
#                                      Year  Life expectancy   Adult Mortality  \
# Year                             1.000000          0.170033        -0.079052
# Life expectancy                  0.170033          1.000000        -0.696359
# Adult Mortality                 -0.079052         -0.696359         1.000000
# infant deaths                   -0.037415         -0.196557         0.078756
# Alcohol                         -0.052990          0.404877        -0.195848
# percentage expenditure           0.031400          0.381864        -0.242860
# Hepatitis B                      0.104333          0.256762        -0.162476
# Measles                         -0.082493         -0.157586         0.031176
#  BMI                             0.108974          0.567694        -0.387017
# under-five deaths               -0.042937         -0.222529         0.094146
# Polio                            0.094158          0.465556        -0.274823
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Plotting the histogram of life expectancy to see how it is distributed in dataset

# %%
plt.figure(figsize=(20,10))
plt.hist(df["Life expectancy "])
plt.xlabel("Life expectancy")
plt.ylabel("count")
plt.title("Life expectancy count")
# Out:
# Text(0.5, 1.0, 'Life expectancy count')

# %% [markdown]
# # plotting line plot of life expectancy with years

# %%
sns.lineplot(df["Year"],df["Life expectancy "])
plt.ylabel("Life expectancy")
plt.xlabel("year")
plt.title("Life expectancy count")
# Out:
# F:\C-Backup\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Life expectancy count')

# %%
import matplotlib

# %%
matplotlib.rcParams['font.size'] = 19
matplotlib.rcParams['figure.figsize'] = (20, 12)
matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %% [markdown]
# # checking how life expentancy varies with schooling

# %%
sns.scatterplot(df["Life expectancy "],df["Schooling"],hue=df["Status"])
plt.xlabel("life expectancy")
plt.ylabel("schooling")
plt.title("life expectancy vs schooling")
# Out:
# F:\C-Backup\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'life expectancy vs schooling')

# %% [markdown]
# # life expectancy vs status

# %%
sns.violinplot(df["Status"], df["Life expectancy "])
plt.xlabel("status")
plt.ylabel("life expectancy")
# Out:
# F:\C-Backup\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'life expectancy')

# %% [markdown]
# # scatterlpot of life expectancy with income
# and we are seeing the higher income means higher life expectancy

# %%
sns.scatterplot(df["Life expectancy "],df["Income composition of resources"],hue=df["Status"])
plt.xlabel("life expectancy")
plt.ylabel("Income composition of resources")
plt.title("life expectancy vs income")
# Out:
# F:\C-Backup\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'life expectancy vs income')

# %% [markdown]
# life expectancy is inversely propostional to the the adult mortality as show in chart below

# %%
sns.scatterplot(df["Life expectancy "],df["Adult Mortality"],hue=df["Status"])
plt.xlabel("life expectancy")
plt.ylabel("Adult mortality")
plt.title("life expectancy vs adult mortality")
# Out:
# F:\C-Backup\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'life expectancy vs adult mortality')

# %%
df["Status"]=df["Status"].map({'Developing':1, 'Developed': 0})

# %%
df
# Out:
#           Country  Year  Status  Life expectancy   Adult Mortality  \
# 0     Afghanistan  2015       1              65.0            263.0
# 1     Afghanistan  2014       1              59.9            271.0
# 2     Afghanistan  2013       1              59.9            268.0
# 3     Afghanistan  2012       1              59.5            272.0
# 4     Afghanistan  2011       1              59.2            275.0
# ...           ...   ...     ...               ...              ...
# 2933     Zimbabwe  2004       1              44.3            723.0
# 2934     Zimbabwe  2003       1              44.5            715.0
# 2935     Zimbabwe  2002       1              44.8             73.0
# 2936     Zimbabwe  2001       1              45.3            686.0
# 2937     Zimbabwe  2000       1              46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 0                62     0.01               71.279624         65.0      1154
# ...

# %%
x=df[["Status","Adult Mortality","Income composition of resources","Schooling"]]
y=df["Life expectancy "]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10700\2843796191.py in <module>
# ----> 1 x=df[["Status","Adult Mortality","Income composition of resources","Schooling"]]
#       2 y=df["Life expectancy "]
#
# NameError: name 'df' is not defined

# %%
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# using standard scaler to make values to be in same range

# %%
scaler = StandardScaler()
scaler.fit(x[["Adult Mortality","Income composition of resources","Schooling"]])
# Out:
# StandardScaler()

# %%
from sklearn.model_selection import train_test_split
from sklearn import metrics
import numpy as np

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y)

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
def rmse(targets, predictions):
    return np.sqrt(np.mean(np.square(targets - predictions)))

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
predictions=model.predict(x_test)

# %%
root_mean_square_error=rmse(y_test,predictions)

# %%
root_mean_square_error
# Out:
# 4.7880449421475575

# %%
print('r2score',metrics.r2_score(y_test,predictions))
# Out:
# r2score 0.7223142799531626

# %%
testoutput=pd.DataFrame({
    "actual_value":y_test,
    "predicted_value":predictions
})

# %%
testout
# Out:
#       actual_value  predicted_value
# 1201          62.5        61.986777
# 2609          65.8        66.984778
# 1792          63.2        60.756238
# 2719          58.4        59.636089
# 2892          65.4        62.658510
# ...            ...              ...
# 893           55.0        53.174182
# 2730          71.3        72.033913
# 935           81.3        77.628455
# 493           51.6        67.603304
# 1742          73.6        71.764884
#
# [735 rows x 2 columns]
